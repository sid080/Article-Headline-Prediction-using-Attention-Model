# %% [markdown]
# <a href="https://colab.research.google.com/github/sid080/Article-Headline-Prediction-using-Attention-Model/blob/master/Headline_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *** Article Headline Prediction using Sequence Models***

# %% [markdown]
# **Loading Dependencies**

# %%
import keras                                               
from keras.datasets import reuters
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.layers import Embedding 
from random import randint
from numpy import array
from numpy import argmax
from numpy import array_equal
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.layers import RepeatVector
from keras.callbacks import ModelCheckpoint 
from sklearn.metrics import roc_auc_score, roc_curve
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Building Attention Layer**

# %%
import tensorflow as tf
from keras import backend as K
from keras import regularizers, constraints, initializers, activations
from keras.layers.recurrent import Recurrent
from keras.engine import InputSpec

tfPrint = lambda d, T: tf.Print(input_=T, data=[T, tf.shape(T)], message=d)

class AttentionDecoder(Recurrent):

    def __init__(self, units, output_dim,
                 activation='tanh',
                 return_probabilities=False,
                 name='AttentionDecoder',
                 kernel_initializer='glorot_uniform',
                 recurrent_initializer='orthogonal',
                 bias_initializer='zeros',
                 kernel_regularizer=None,
                 bias_regularizer=None,
                 activity_regularizer=None,
                 kernel_constraint=None,
                 bias_constraint=None,
                 **kwargs):
        """
        Implements an AttentionDecoder that takes in a sequence encoded by an
        encoder and outputs the decoded states
        :param units: dimension of the hidden state and the attention matrices
        :param output_dim: the number of labels in the output space

        references:
            Bahdanau, Dzmitry, Kyunghyun Cho, and Yoshua Bengio.
            "Neural machine translation by jointly learning to align and translate."
            arXiv preprint arXiv:1409.0473 (2014).
        """
        self.units = units
        self.output_dim = output_dim
        self.return_probabilities = return_probabilities
        self.activation = activations.get(activation)
        self.kernel_initializer = initializers.get(kernel_initializer)
        self.recurrent_initializer = initializers.get(recurrent_initializer)
        self.bias_initializer = initializers.get(bias_initializer)

        self.kernel_regularizer = regularizers.get(kernel_regularizer)
        self.recurrent_regularizer = regularizers.get(kernel_regularizer)
        self.bias_regularizer = regularizers.get(bias_regularizer)
        self.activity_regularizer = regularizers.get(activity_regularizer)

        self.kernel_constraint = constraints.get(kernel_constraint)
        self.recurrent_constraint = constraints.get(kernel_constraint)
        self.bias_constraint = constraints.get(bias_constraint)

        super(AttentionDecoder, self).__init__(**kwargs)
        self.name = name
        self.return_sequences = True  # must return sequences

    def build(self, input_shape):
        """
          See Appendix 2 of Bahdanau 2014, arXiv:1409.0473
          for model details that correspond to the matrices here.
        """

        self.batch_size, self.timesteps, self.input_dim = input_shape

        if self.stateful:
            super(AttentionDecoder, self).reset_states()

        self.states = [None, None]  # y, s

        """
            Matrices for creating the context vector
        """

        self.V_a = self.add_weight(shape=(self.units,),
                                   name='V_a',
                                   initializer=self.kernel_initializer,
                                   regularizer=self.kernel_regularizer,
                                   constraint=self.kernel_constraint)
        self.W_a = self.add_weight(shape=(self.units, self.units),
                                   name='W_a',
                                   initializer=self.kernel_initializer,
                                   regularizer=self.kernel_regularizer,
                                   constraint=self.kernel_constraint)
        self.U_a = self.add_weight(shape=(self.input_dim, self.units),
                                   name='U_a',
                                   initializer=self.kernel_initializer,
                                   regularizer=self.kernel_regularizer,
                                   constraint=self.kernel_constraint)
        self.b_a = self.add_weight(shape=(self.units,),
                                   name='b_a',
                                   initializer=self.bias_initializer,
                                   regularizer=self.bias_regularizer,
                                   constraint=self.bias_constraint)
        """
            Matrices for the r (reset) gate
        """
        self.C_r = self.add_weight(shape=(self.input_dim, self.units),
                                   name='C_r',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.U_r = self.add_weight(shape=(self.units, self.units),
                                   name='U_r',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.W_r = self.add_weight(shape=(self.output_dim, self.units),
                                   name='W_r',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.b_r = self.add_weight(shape=(self.units, ),
                                   name='b_r',
                                   initializer=self.bias_initializer,
                                   regularizer=self.bias_regularizer,
                                   constraint=self.bias_constraint)

        """
            Matrices for the z (update) gate
        """
        self.C_z = self.add_weight(shape=(self.input_dim, self.units),
                                   name='C_z',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.U_z = self.add_weight(shape=(self.units, self.units),
                                   name='U_z',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.W_z = self.add_weight(shape=(self.output_dim, self.units),
                                   name='W_z',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.b_z = self.add_weight(shape=(self.units, ),
                                   name='b_z',
                                   initializer=self.bias_initializer,
                                   regularizer=self.bias_regularizer,
                                   constraint=self.bias_constraint)
        """
            Matrices for the proposal
        """
        self.C_p = self.add_weight(shape=(self.input_dim, self.units),
                                   name='C_p',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.U_p = self.add_weight(shape=(self.units, self.units),
                                   name='U_p',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.W_p = self.add_weight(shape=(self.output_dim, self.units),
                                   name='W_p',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.b_p = self.add_weight(shape=(self.units, ),
                                   name='b_p',
                                   initializer=self.bias_initializer,
                                   regularizer=self.bias_regularizer,
                                   constraint=self.bias_constraint)
        """
            Matrices for making the final prediction vector
        """
        self.C_o = self.add_weight(shape=(self.input_dim, self.output_dim),
                                   name='C_o',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.U_o = self.add_weight(shape=(self.units, self.output_dim),
                                   name='U_o',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.W_o = self.add_weight(shape=(self.output_dim, self.output_dim),
                                   name='W_o',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)
        self.b_o = self.add_weight(shape=(self.output_dim, ),
                                   name='b_o',
                                   initializer=self.bias_initializer,
                                   regularizer=self.bias_regularizer,
                                   constraint=self.bias_constraint)

        # For creating the initial state:
        self.W_s = self.add_weight(shape=(self.input_dim, self.units),
                                   name='W_s',
                                   initializer=self.recurrent_initializer,
                                   regularizer=self.recurrent_regularizer,
                                   constraint=self.recurrent_constraint)

        self.input_spec = [
            InputSpec(shape=(self.batch_size, self.timesteps, self.input_dim))]
        self.built = True

    def call(self, x):
        # store the whole sequence so we can "attend" to it at each timestep
        self.x_seq = x

        # apply the a dense layer over the time dimension of the sequence
        # do it here because it doesn't depend on any previous steps
        # thefore we can save computation time:
        self._uxpb = _time_distributed_dense(self.x_seq, self.U_a, b=self.b_a,
                                             input_dim=self.input_dim,
                                             timesteps=self.timesteps,
                                             output_dim=self.units)

        return super(AttentionDecoder, self).call(x)

    def get_initial_state(self, inputs):
        # apply the matrix on the first time step to get the initial s0.
        s0 = activations.tanh(K.dot(inputs[:, 0], self.W_s))

        # from keras.layers.recurrent to initialize a vector of (batchsize,
        # output_dim)
        y0 = K.zeros_like(inputs)  # (samples, timesteps, input_dims)
        y0 = K.sum(y0, axis=(1, 2))  # (samples, )
        y0 = K.expand_dims(y0)  # (samples, 1)
        y0 = K.tile(y0, [1, self.output_dim])

        return [y0, s0]

    def step(self, x, states):

        ytm, stm = states

        # repeat the hidden state to the length of the sequence
        _stm = K.repeat(stm, self.timesteps)

        # now multiplty the weight matrix with the repeated hidden state
        _Wxstm = K.dot(_stm, self.W_a)

        # calculate the attention probabilities
        # this relates how much other timesteps contributed to this one.
        et = K.dot(activations.tanh(_Wxstm + self._uxpb),
                   K.expand_dims(self.V_a))
        at = K.exp(et)
        at_sum = K.sum(at, axis=1)
        at_sum_repeated = K.repeat(at_sum, self.timesteps)
        at /= at_sum_repeated  # vector of size (batchsize, timesteps, 1)

        # calculate the context vector
        context = K.squeeze(K.batch_dot(at, self.x_seq, axes=1), axis=1)
        # ~~~> calculate new hidden state
        # first calculate the "r" gate:

        rt = activations.sigmoid(
            K.dot(ytm, self.W_r)
            + K.dot(stm, self.U_r)
            + K.dot(context, self.C_r)
            + self.b_r)

        # now calculate the "z" gate
        zt = activations.sigmoid(
            K.dot(ytm, self.W_z)
            + K.dot(stm, self.U_z)
            + K.dot(context, self.C_z)
            + self.b_z)

        # calculate the proposal hidden state:
        s_tp = activations.tanh(
            K.dot(ytm, self.W_p)
            + K.dot((rt * stm), self.U_p)
            + K.dot(context, self.C_p)
            + self.b_p)

        # new hidden state:
        st = (1-zt)*stm + zt * s_tp

        yt = activations.softmax(
            K.dot(ytm, self.W_o)
            + K.dot(stm, self.U_o)
            + K.dot(context, self.C_o)
            + self.b_o)

        if self.return_probabilities:
            return at, [yt, st]
        else:
            return yt, [yt, st]

    def compute_output_shape(self, input_shape):
        """
            For Keras internal compatability checking
        """
        if self.return_probabilities:
            return (None, self.timesteps, self.timesteps)
        else:
            return (None, self.timesteps, self.output_dim)

    def get_config(self):
        """
            For rebuilding models on load time.
        """
        config = {
            'output_dim': self.output_dim,
            'units': self.units,
            'return_probabilities': self.return_probabilities
        }
        base_config = super(AttentionDecoder, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# **Building Time Distributed Dense Layer**

# %%
def _time_distributed_dense(x, w, b=None, dropout=None,
                            input_dim=None, output_dim=None,
                            timesteps=None, training=None):
    """Apply `y . w + b` for every temporal slice y of x.
    # Arguments
        x: input tensor.
        w: weight matrix.
        b: optional bias vector.
        dropout: wether to apply dropout (same dropout mask
            for every temporal slice of the input).
        input_dim: integer; optional dimensionality of the input.
        output_dim: integer; optional dimensionality of the output.
        timesteps: integer; optional number of timesteps.
        training: training phase tensor or boolean.
    # Returns
        Output tensor.
    """
    if not input_dim:
        input_dim = K.shape(x)[2]
    if not timesteps:
        timesteps = K.shape(x)[1]
    if not output_dim:
        output_dim = K.shape(w)[1]

    if dropout is not None and 0. < dropout < 1.:
        # apply the same dropout pattern at every timestep
        ones = K.ones_like(K.reshape(x[:, 0, :], (-1, input_dim)))
        dropout_matrix = K.dropout(ones, dropout)
        expanded_dropout_matrix = K.repeat(dropout_matrix, timesteps)
        x = K.in_train_phase(x * expanded_dropout_matrix, x, training=training)

    # collapse time dimension and batch dimension together
    x = K.reshape(x, (-1, input_dim))
    x = K.dot(x, w)
    if b is not None:
        x = K.bias_add(x, b)
    # reshape to 3D tensor
    if K.backend() == 'tensorflow':
        x = K.reshape(x, K.stack([-1, timesteps, output_dim]))
        x.set_shape([None, None, output_dim])
    else:
        x = K.reshape(x, (-1, timesteps, output_dim))
    return x

# %% [markdown]
# **Hyperparameters**

# %%
 #output directory name:
output_dir = 'content/dense'

# training:
epochs = 5000
batch_size = 128

# vector-space embedding: 
n_dim = 64
n_unique_words = 5000 # as per Maas et al. (2011); may not be optimal
n_words_to_skip = 50 
max_review_length = 100
pad_type = trunc_type = 'pre'

# %% [markdown]
# **Study reuters dataset**

# %%
(x_train, y_train), (x_test, y_test) = reuters.load_data(path="reuters.npz",
                                                         num_words=5000,
                                                         skip_top=0,
                                                         maxlen=50,
                                                         test_split=0.2,
                                                         seed=113,
                                                         start_char=1,
                                                         oov_char=2,
                                                         index_from=3)
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step

# %%
x_train[0]
# Out:
# [1,
#  245,
#  273,
#  207,
#  156,
#  53,
#  74,
#  160,
#  26,
#  14,
#  46,
#  296,
#  26,
#  39,
#  74,
#  2979,
#  3554,
#  14,
#  46,
#  4689,
#  4329,
#  86,
#  61,
#  3499,
#  4795,
#  14,
#  61,
#  451,
#  4329,
#  17,
#  12]

# %% [markdown]
# **Data Preprocessing**

# %%
word_index = keras.datasets.reuters.get_word_index()
word_index = {k:(v+3) for k,v in word_index.items()}
word_index["PAD"] = 0
word_index["START"] = 1
word_index["UNK"] = 2
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/reuters_word_index.json
# 557056/550378 [==============================] - 0s 0us/step

# %%
word_index
# Out:
# {'mdbl': 10999,
#  'fawc': 16263,
#  'degussa': 12092,
#  'woods': 8806,
#  'hanging': 13799,
#  'localized': 20675,
#  'sation': 20676,
#  'chanthaburi': 20678,
#  'refunding': 11000,
#  'hermann': 8807,
#  'passsengers': 20679,
#  'stipulate': 20680,
#  'heublein': 8355,
#  'screaming': 20716,
#  'tcby': 16264,
#  'four': 188,
#  'grains': 1645,
#  'broiler': 20683,
#  'wooden': 12093,
#  'wednesday': 1223,
#  'highveld': 13800,
#  'duffour': 7596,
#  '0053': 20684,
#  'elections': 3917,
#  '270': 2566,
#  '271': 3554,
#  '272': 5116,
#  '273': 3555,
#  '274': 3403,
#  'rudman': 7978,
#  '276': 3404,
#  '277': 3481,
#  '278': 3635,
#  '279': 4312,
#  'dormancy': 9384,
#  'errors': 7250,
#  'deferred': 3089,
#  'sptnd': 20686,
#  'cooking': 8808,
#  'stratabit': 20687,
#  'designing': 16265,
#  'metalurgicos': 20688,
#  'databank': 13801,
#  '300er': 20689,
#  'shocks': 20690,
#  'nawg': 7975,
#  'tnta': 20691,
#  'perforations': 20692,
#  'affiliates': 2894,
#  '27p': 20693,
#  'ching': 16266,
#  'china': 598,
#  'wagyu': 16267,
#  'affiliated': 3192,
#  'chino': 16268,
#  'chinh': 16269,
#  'slickline': 20695,
#  'doldrums': 13802,
#  'kids': 12095,
#  'climbed': 3031,
#  'controversy': 6696,
#  'kidd': 20696,
#  'spotty': 12096,
#  'rebel': 12642,
#  'millimetres': 9385,
#  'golden': 4010,
#  'projection': 5692,
#  'stern': 12097,
#  "hudson's": 7906,
#  'dna': 10069,
#  'dnc': 20698,
#  'hodler': 20699,
#  'lme': 2397,
#  'insolvancy': 20700,
#  'music': 13803,
#  'therefore': 1987,
#  'dns': 11001,
#  'distortions': 6962,
#  'thassos': 13804,
#  'populations': 20701,
#  'meteorologist': 8809,
#  'loss': 46,
#  'exco': 9386,
#  'adventist': 20816,
#  'murchison': 16270,
#  'locked': 11002,
#  'kampala': 13805,
#  'arndt': 20702,
#  'nakasone': 1270,
#  'steinweg': 20703,
#  "india's": 3636,
#  'wang': 3032,
#  'wane': 10070,
#  'unjust': 13806,
#  'titanium': 13807,
#  'want': 853,
#  'pinto': 20704,
#  "institutes'": 16271,
#  'absolute': 7976,
#  'travel': 4680,
#  'cutback': 6425,
#  'nazmi': 16272,
#  'modest': 1861,
#  'shopwell': 16273,
#  'sedi': 20705,
#  'adoped': 20706,
#  'tulis': 16274,
#  '18th': 20707,
#  "wmc's": 20708,
#  'menlo': 20709,
#  'reiners': 11003,
#  'farmlands': 12098,
#  'nonsensical': 20710,
#  'elisra': 20711,
#  'welcomed': 2464,
#  'peup': 20712,
#  "holiday's": 16275,
#  'activating': 20714,
#  'avondale': 16276,
#  'interational': 16277,
#  'welcomes': 20715,
#  'fip': 16278,
#  'tailings': 11004,
#  'fit': 4208,
#  'lifeline': 16279,
#  'bringing': 1919,
#  'fix': 4822,
#  '624': 6167,
#  'naturalite': 12099,
#  'wales': 6168,
#  'fin': 8810,
#  'fio': 11132,
#  'ceremenony': 20717,
#  'sovr': 20718,
#  "yeo's": 20719,
#  'effects': 1791,
#  'sixteen': 13808,
#  'undeveloped': 8811,
#  'glutted': 13809,
#  'barton': 20720,
#  'froday': 20721,
#  'arrow': 10092,
#  'stabilises': 11005,
#  'allan': 6963,
#  '374p': 20722,
#  '393': 3894,
#  '392': 4011,
#  '391': 4209,
#  '390': 3082,
#  '397': 4553,
#  '396': 6169,
#  '395': 6426,
#  '394': 4210,
#  '399': 6964,
#  '398': 4211,
#  'stabilised': 7598,
#  'smelters': 5117,
#  'oprah': 20723,
#  'orginially': 20724,
#  "tvx's": 20725,
#  'ponomarev': 16281,
#  'enviroment': 20726,
#  "reeves'": 20727,
#  'mason': 8366,
#  'encourage': 1673,
#  'adapt': 7599,
#  'abbott': 12779,
#  'stamping': 13811,
#  'colquiri': 20729,
#  'ambrit': 11006,
#  'strata': 8356,
#  'corrects': 4824,
#  'sandra': 11925,
#  'estimate': 862,
#  'universally': 20730,
#  'chlorine': 20731,
#  'competes': 16282,
#  'leiner': 10071,
#  'ministries': 8812,
#  'disturbed': 8813,
#  'competed': 13812,
#  'juergen': 8814,
#  'kfw': 13813,
#  'turben': 11007,
#  'reintroduced': 9387,
#  'maladies': 20732,
#  'chevron': 4104,
#  'lazere': 16283,
#  'antilles': 8815,
#  'dti': 11910,
#  'specially': 9073,
#  'bilzerian': 4681,
#  'bakelite': 13814,
#  'renovated': 20733,
#  'service': 571,
#  'payless': 16284,
#  'spiegler': 20734,
#  'needed': 834,
#  'wigglesworth': 16285,
#  'master': 6965,
#  'antonson': 13815,
#  'genesis': 20735,
#  'vismara': 13816,
#  'organically': 20737,
#  "accords'": 20738,
#  'task': 5943,
#  'positively': 7977,
#  'feasibility': 3482,
#  'ahmed': 6966,
#  "suralco's": 13817,
#  'awacs': 20739,
#  'idly': 16286,
#  'regulator': 20740,
#  'pseudorabies': 12100,
#  'staubli': 16287,
#  'nzi': 8816,
#  'feeling': 5118,
#  '275': 3130,
#  '6819': 20741,
#  'gorman': 16288,
#  'sustaining': 8357,
#  'spectrum': 9388,
#  'consenting': 20742,
#  'recapitalized': 12101,
#  'sailed': 11565,
#  'dozen': 7600,
#  'affairs': 1988,
#  'courier': 2256,
#  'kremlin': 8358,
#  'shipments': 898,
#  "aquino's": 16289,
#  'committing': 10073,
#  'sugarcane': 5296,
#  'diminishing': 9389,
#  'vexing': 16290,
#  'simplify': 11008,
#  'mouth': 6170,
#  'steinhardt': 7251,
#  'conceded': 8817,
#  'bradford': 9390,
#  'singer': 7979,
#  '5602': 20743,
#  "1987's": 13819,
#  'tech': 4953,
#  'teck': 6427,
#  'majv': 20744,
#  'saying': 669,
#  'dickey': 16480,
#  'sweetner': 20745,
#  'teresa': 21152,
#  'ulcer': 20746,
#  'cheaply': 13820,
#  'thai': 2364,
#  'orleans': 6967,
#  'excavator': 16293,
#  'rico': 6171,
#  'lube': 12102,
#  'rick': 13821,
#  'rich': 4682,
#  'kerna': 13822,
#  'rice': 953,
#  'rica': 4212,
#  'plate': 5506,
#  'platt': 16294,
#  'altogether': 8359,
#  'jaguar': 8818,
#  'dynair': 20747,
#  'patch': 8819,
#  'ldp': 2895,
#  'boarded': 13823,
#  'precluding': 16295,
#  'clarified': 11009,
#  'sensitivity': 16296,
#  'alternative': 1514,
#  'clarifies': 11010,
#  'lots': 5119,
#  'irs': 7601,
#  'irv': 20748,
#  'iri': 13824,
#  'ira': 13825,
#  'timber': 5693,
#  'ire': 20749,
#  'discipline': 5222,
#  'extend': 1940,
#  'nature': 3637,
#  "amb's": 16298,
#  'dunhill': 16299,
#  'extent': 2145,
#  'restrcitions': 20750,
#  'heating': 2399,
#  "mannesmann's": 11011,
#  'outsanding': 20751,
#  'multimillions': 20752,
#  'sarcinelli': 13827,
#  'southeastern': 6697,
#  'eradicate': 10074,
#  'libyan': 9391,
#  'foreclosing': 20753,
#  'maclaine': 12104,
#  'fra': 20754,
#  'union': 356,
#  'frn': 11012,
#  'much': 389,
#  'fry': 12105,
#  'mothball': 20755,
#  'chlorazepate': 10075,
#  'dxns': 12106,
#  'toyko': 19984,
#  'spit': 20756,
#  '007050': 16300,
#  'freehold': 16301,
#  'davy': 13828,
#  'dave': 11013,
#  'spie': 12180,
#  'aguayo': 10120,
#  'wildcat': 12107,
#  'fecs': 10072,
#  'kennan': 20757,
#  'intal': 16302,
#  'contingencies': 9392,
#  'professionally': 16554,
#  'microbiological': 16303,
#  'misconstrued': 20759,
#  'k': 412,
#  'securitiesd': 20760,
#  'deferring': 16304,
#  'kohl': 5944,
#  'conditioned': 3033,
#  'fnhb': 20761,
#  "october's": 16305,
#  'memorial': 13957,
#  'democracies': 6968,
#  'conformed': 27523,
#  'split': 467,
#  "bond's": 12108,
#  'thinly': 11115,
#  'dunkirk': 16518,
#  'cavanaugh': 16306,
#  "securities'": 13830,
#  'marches': 21348,
#  'issam': 16307,
#  'workforce': 2023,
#  'meinert': 12109,
#  'boiler': 13831,
#  "bp's": 5297,
#  'torpedoed': 16308,
#  'indidate': 20765,
#  'downwardly': 13832,
#  'viviez': 20766,
#  'vladiminovich': 20767,
#  'academic': 16309,
#  'architecural': 20768,
#  'corporate': 1120,
#  'appropriately': 16310,
#  'teicc': 20769,
#  "hanover's": 20770,
#  'aristech': 8820,
#  'portrayed': 20771,
#  'raffineries': 21386,
#  'hai': 20773,
#  'hal': 7602,
#  'ham': 13833,
#  'han': 10076,
#  'e15b': 20774,
#  'had': 64,
#  'hay': 20775,
#  'botchwey': 13834,
#  'haq': 10077,
#  'has': 40,
#  'hat': 13835,
#  'hav': 20776,
#  'fortin': 20777,
#  'municipal': 8821,
#  'osman': 20778,
#  'fsical': 20779,
#  'elders': 3483,
#  'survival': 12110,
#  'unequivocally': 16311,
#  'objective': 2522,
#  'indicative': 6698,
#  'shadow': 10078,
#  'riskiness': 21414,
#  'positiive': 20781,
#  "american's": 10079,
#  'alick': 16312,
#  'harima': 16313,
#  'alice': 12111,
#  'altschul': 20782,
#  'festivities': 16314,
#  'medecines': 20783,
#  'beneficial': 2945,
#  'yoweri': 12112,
#  'crowd': 13836,
#  'crowe': 9393,
#  'crown': 3556,
#  'topping': 13682,
#  'captive': 8822,
#  'billboard': 12113,
#  'fiduciary': 6172,
#  'bottom': 3405,
#  'plucked': 20785,
#  'locksmithing': 20786,
#  'ecopetrol': 9394,
#  'pipestone': 24021,
#  "growers'": 5508,
#  'borrows': 20788,
#  'eduard': 16315,
#  'venpres': 13837,
#  'bamboo': 16316,
#  'foolish': 13838,
#  'uruguyan': 20789,
#  'officeholders': 20790,
#  'economiques': 20791,
#  'aden': 16317,
#  'maxwell': 4825,
#  'marshall': 4683,
#  'honeymoon': 16318,
#  'administer': 16319,
#  'shoots': 20793,
#  'rubbertech': 16320,
#  'johsen': 16321,
#  'reciprocity': 10080,
#  'fabric': 13839,
#  'suffice': 20794,
#  'spokemsan': 20795,
#  "sonora's": 20796,
#  '5865': 16322,
#  "systems'": 16323,
#  'perfumes': 20797,
#  'halycon': 20798,
#  'nonvoting': 20799,
#  'safeguard': 7253,
#  'sawdust': 21541,
#  "else's": 20800,
#  'arrays': 13840,
#  'aza': 20801,
#  'smasher': 20802,
#  'complications': 12114,
#  'pesos': 1816,
#  'relabelling': 20803,
#  'passenger': 3725,
#  "avon's": 12115,
#  'megahertz': 20804,
#  'mirror': 10686,
#  'minas': 8360,
#  'bourdain': 16325,
#  'crownx': 20805,
#  'eventual': 6428,
#  'crowns': 1210,
#  'role': 1372,
#  'obliges': 20806,
#  'rolf': 16326,
#  'vegetative': 13841,
#  'rolm': 20807,
#  'roll': 4422,
#  'intend': 2466,
#  'palms': 16327,
#  'denys': 19258,
#  'transported': 13842,
#  'moresby': 20808,
#  'devon': 16328,
#  'intent': 1354,
#  "camco's": 20809,
#  'variable': 5945,
#  'transporter': 20810,
#  'danske': 16329,
#  'friedhelm': 13843,
#  'hawker': 8361,
#  "sand's": 17777,
#  'preseving': 20811,
#  '80386': 12116,
#  'bnls': 16331,
#  'ordination': 19987,
#  'overturned': 11014,
#  'erred': 16332,
#  'cincinnati': 6699,
#  'corps': 16713,
#  'whoever': 20812,
#  'osp': 16333,
#  'osr': 13844,
#  'ost': 12117,
#  'chair': 16334,
#  '690': 5650,
#  'grapples': 20813,
#  'megawatts': 13845,
#  'photocopiers': 20814,
#  'sconninx': 20815,
#  'circumstances': 2277,
#  'oversight': 13846,
#  "paradyne's": 20817,
#  '691': 6366,
#  'paychecks': 20818,
#  "stadelmann's": 13847,
#  'choice': 3244,
#  'vastagh': 11015,
#  'embark': 8823,
#  'gloomy': 9395,
#  'stays': 9396,
#  'exact': 4012,
#  'minute': 5120,
#  'kittiwake': 11895,
#  'picul': 20819,
#  'skewed': 20820,
#  'cooke': 11016,
#  'defaults': 10081,
#  'reimpose': 11017,
#  'hindered': 9397,
#  'lengthened': 20821,
#  'chopping': 16336,
#  'mckiernan': 13848,
#  'collaspe': 20822,
#  'corazon': 7254,
#  'antwerp': 7603,
#  'abdullah': 13849,
#  'goldston': 13850,
#  '300': 445,
#  'cassa': 20824,
#  'casse': 20825,
#  '695': 4084,
#  'ground': 2982,
#  'boost': 842,
#  'azusa': 16337,
#  'drafted': 9398,
#  '303': 4826,
#  'climbs': 13851,
#  'honour': 7604,
#  'vanderbilt': 20826,
#  '305': 3971,
#  'address': 3034,
#  'dwindling': 8824,
#  'benson': 7255,
#  'enroll': 12118,
#  'revenues': 504,
#  'impacted': 12119,
#  'queue': 20829,
#  'accomplished': 10082,
#  'throughput': 7605,
#  'influx': 9399,
#  'stockbuilding': 10083,
#  'aproximates': 20830,
#  'petroleo': 13852,
#  'sistemas': 16338,
#  'feretti': 14056,
#  'opposes': 5946,
#  'working': 885,
#  'perished': 20832,
#  'oldham': 13853,
#  '27000': 20833,
#  'optimize': 19248,
#  'vigour': 20835,
#  'opposed': 1583,
#  'liberalizing': 16339,
#  'wvz': 20836,
#  'dampness': 20837,
#  'approving': 13854,
#  'sierra': 13499,
#  'entrepot': 20838,
#  'currency': 227,
#  'originally': 1502,
#  'tindemans': 20840,
#  'valorem': 16340,
#  'following': 480,
#  'fossen': 20841,
#  'locke': 11019,
#  'employess': 20842,
#  'rotberg': 12120,
#  'parachute': 16341,
#  'locks': 11020,
#  'incremental': 12258,
#  'woolowrth': 16342,
#  'listens': 20844,
#  'litre': 7256,
#  'edouard': 3557,
#  'ounce': 1380,
#  'nicanor': 20846,
#  'sucocitrico': 20847,
#  'minicomputers': 16343,
#  "silva's": 16344,
#  'restitutions': 11021,
#  'custer': 16345,
#  '3rd': 2593,
#  'fueled': 10084,
#  'trydahl': 20848,
#  'aice': 11022,
#  'harmon': 12121,
#  'conscious': 10085,
#  'herbicidesand': 20849,
#  'subdivisions': 20850,
#  "veslefrikk's": 20851,
#  'swollen': 11023,
#  'pulled': 7981,
#  'tilney': 20852,
#  'years': 206,
#  'structuring': 20853,
#  'episodes': 20854,
#  'sportscene': 16346,
#  "northair's": 16347,
#  'jig': 20855,
#  'jin': 20856,
#  'jim': 3406,
#  'troubles': 8362,
#  'workforces': 13855,
#  'suspension': 2365,
#  'troubled': 3895,
#  'fondiaria': 16348,
#  'modestly': 6700,
#  'recipients': 12122,
#  'civilian': 7982,
#  'indigenous': 13856,
#  'overpowering': 20857,
#  'drilling': 1054,
#  'sorted': 16349,
#  'lichtenstein': 16350,
#  'bedevil': 20858,
#  'dispite': 20859,
#  'battleships': 16846,
#  'instability': 4827,
#  'quarter': 98,
#  'salado': 20860,
#  'honduras': 5695,
#  "chevron's": 13858,
#  "lazere's": 12276,
#  'receipt': 2663,
#  'sponsor': 8363,
#  'entering': 4828,
#  "kcbt's": 16352,
#  'nowicki': 19990,
#  'salads': 13859,
#  'augar': 16354,
#  '797': 7983,
#  '796': 7257,
#  '795': 8364,
#  '794': 5298,
#  '793': 5121,
#  '792': 6173,
#  '791': 5299,
#  '790': 4829,
#  "nikko's": 20861,
#  'unsaleable': 20862,
#  '799': 5723,
#  '798': 5696,
#  'seriously': 2146,
#  'trauma': 16355,
#  'tvbh': 20863,
#  'macedon': 20864,
#  'disintegrated': 21909,
#  'adddition': 21912,
#  'incentives': 2247,
#  'complicated': 5947,
#  'reevaluating': 20867,
#  'thatching': 21924,
#  'brasil': 7984,
#  '79p': 20868,
#  'wrong': 4954,
#  'initiate': 8825,
#  'aboard': 16356,
#  'saving': 7258,
#  'spoken': 8826,
#  'parkinson': 16367,
#  'one': 68,
#  'ont': 20870,
#  'concert': 7259,
#  "boston's": 16357,
#  'stifled': 13862,
#  'types': 4625,
#  'lingering': 20871,
#  'surges': 16359,
#  'hurdman': 20872,
#  'herds': 16360,
#  'absorbs': 14117,
#  'surged': 4684,
#  'dalkon': 14214,
#  'crossroads': 13863,
#  'shakeup': 20873,
#  'disasterous': 20874,
#  'illness': 11024,
#  'turned': 3245,
#  'locations': 3804,
#  'tyranite': 12123,
#  'minesweepers': 13864,
#  'turner': 7260,
#  'borough': 20875,
#  'underlines': 12361,
#  "bancorporation's": 20876,
#  'fashionable': 20877,
#  "ae's": 20878,
#  'dilutions': 16361,
#  'goodman': 9475,
#  'unlawfully': 10513,
#  'mayer': 16362,
#  'printer': 16363,
#  'offload': 20880,
#  'opposite': 13865,
#  'buffer': 741,
#  'printed': 9401,
#  'pequiven': 16364,
#  'panoche': 13866,
#  'knowingly': 20881,
#  'ecusta': 16365,
#  'thsl': 20882,
#  'phil': 8828,
#  'jitters': 13867,
#  'touche': 16366,
#  'jittery': 20884,
#  'friction': 3294,
#  'fecal': 16368,
#  'resurgance': 22071,
#  'heeding': 20885,
#  'soviets': 2366,
#  'imagined': 16369,
#  'transact': 16370,
#  'califoirnia': 20886,
#  "chrysler's": 9402,
#  'respecitvely': 16371,
#  'presse': 16372,
#  'euromarket': 10087,
#  'guarded': 12124,
#  'satisfacotry': 16374,
#  'authroization': 20887,
#  'simplistic': 20888,
#  'monde': 20889,
#  'awaiting': 4105,
#  'recombinant': 13868,
#  'refinancement': 20890,
#  'comserv': 20891,
#  'kitakyushu': 20892,
#  'pima': 16375,
#  'basle': 11025,
#  '6250': 20894,
#  'choudhury': 16376,
#  'vision': 8829,
#  'interruptible': 20895,
#  'weatherford': 13869,
#  '832': 7985,
#  '833': 5697,
#  '830': 4423,
#  '831': 5122,
#  '836': 5300,
#  '837': 4556,
#  '834': 6175,
#  '835': 4955,
#  'alarming': 22147,
#  '838': 5698,
#  '839': 6176,
#  '524p': 20896,
#  'sponsorship': 20897,
#  'vendex': 12125,
#  "amsouth's": 20898,
#  'kilometer': 20899,
#  'enjoys': 10089,
#  'illiberal': 20900,
#  'punta': 6177,
#  'punte': 20901,
#  'girozentrale': 10090,
#  'missstatements': 20902,
#  'marietta': 10091,
#  'awards': 6178,
#  'concentrated': 3638,
#  '83p': 20903,
#  'developpement': 13870,
#  'rhodes': 13871,
#  'matheson': 5699,
#  '1720': 20904,
#  'paring': 20905,
#  's': 38,
#  'concentrates': 4956,
#  "can's": 16377,
#  'polysaturated': 22186,
#  'parini': 20906,
#  'baden': 13872,
#  'bader': 20907,
#  'buoyancy': 12126,
#  'erdem': 20908,
#  'properites': 16378,
#  'comparitive': 20909,
#  'practises': 12127,
#  'collides': 20910,
#  'west': 192,
#  'wess': 20911,
#  'collided': 13873,
#  'practised': 20912,
#  "amalgamated's": 20913,
#  'motives': 20914,
#  'wants': 1381,
#  'formed': 1276,
#  'readings': 20915,
#  'geothermal': 12128,
#  'tightened': 7318,
#  "d'or": 11026,
#  'former': 1112,
#  'venezulean': 20916,
#  'curd': 19938,
#  'squeezes': 12129,
#  'newspaper': 1022,
#  'situation': 820,
#  'ivey': 13874,
#  'engaged': 3639,
#  'dubious': 13875,
#  'cayacq': 17064,
#  'cobol': 20919,
#  'limping': 20920,
#  'technology': 886,
#  'koerner': 20922,
#  'debilitating': 16379,
#  'verified': 7986,
#  'otto': 4013,
#  '7770': 20923,
#  'emulsions': 16380,
#  "onic's": 16381,
#  'slate': 9078,
#  'wires': 20924,
#  'edged': 5509,
#  'assigns': 20925,
#  'singapore': 1344,
#  'deflate': 20926,
#  "strategy's": 20927,
#  'walesa': 16382,
#  'advertisement': 4557,
#  'luyten': 20928,
#  'shrortly': 20929,
#  'corpoartion': 20930,
#  'preferance': 22293,
#  'tracking': 16383,
#  'sunnyvale': 13877,
#  'colorants': 20931,
#  'persistently': 16384,
#  "officers'": 16385,
#  "his's": 20932,
#  'being': 370,
#  'divestitures': 7262,
#  'steamer': 20933,
#  'rover': 20934,
#  'grounded': 8365,
#  "businessmen's": 16386,
#  'cyanidation': 16387,
#  'overthrow': 20935,
#  'partnerhip': 20936,
#  'sumt': 16388,
#  'sums': 8830,
#  'oelmuehle': 16389,
#  'unveil': 16390,
#  'gestures': 13878,
#  'penta': 20937,
#  'traffic': 2547,
#  'preference': 2431,
#  'sumi': 20938,
#  'world': 169,
#  'postal': 9403,
#  'bced': 16391,
#  'dornbush': 12131,
#  'confine': 14218,
#  '2555': 20939,
#  "zambia's": 5948,
#  'superiority': 20940,
#  'militate': 20941,
#  'satisfactory': 2398,
#  'superintendent': 20942,
#  'tvx': 5949,
#  'tvt': 16392,
#  'magma': 6701,
#  'diving': 20943,
#  'tvb': 15551,
#  'seaman': 13879,
#  'matsunaga': 11028,
#  '919': 4830,
#  '918': 5301,
#  'refundable': 17073,
#  '914': 5950,
#  '917': 7263,
#  '916': 6702,
#  '911': 5510,
#  '910': 4831,
#  'restoring': 10216,
#  '912': 4558,
#  'squabble': 20945,
#  'retains': 7264,
#  "partner's": 20946,
#  'leadership': 5303,
#  'graaf': 11029,
#  'spacelab': 20947,
#  'thailand': 1803,
#  'graan': 9405,
#  'exasperating': 20948,
#  'hartmarx': 12132,
#  'frights': 16393,
#  'niall': 20949,
#  'johnston': 11030,
#  '91p': 16394,
#  'sensitively': 16395,
#  'porsche': 6019,
#  'prepares': 15497,
#  'lively': 12133,
#  'stoppages': 10689,
#  "associated's": 16397,
#  'pivot': 12134,
#  'series': 1040,
#  'sese': 24053,
#  'bubble': 7607,
#  'trusses': 16398,
#  'interestate': 20952,
#  'continents': 20953,
#  'societal': 20954,
#  'with': 31,
#  'pull': 6179,
#  'rush': 6703,
#  'monopoly': 6225,
#  'operationally': 20956,
#  'dirty': 20957,
#  'abuses': 10093,
#  'prudhoe': 7265,
#  'pulp': 5952,
#  'rust': 16399,
#  'hellman': 20958,
#  'amdec': 20959,
#  'australasian': 16400,
#  'watches': 13881,
#  'hypertension': 20960,
#  "hemdale's": 20961,
#  'formulation': 16401,
#  'watched': 7608,
#  'jargon': 20962,
#  'cream': 13882,
#  'ideally': 9407,
#  'ryavec': 11031,
#  'microoganisms': 20963,
#  'indemnify': 13883,
#  'wincenty': 20964,
#  'waving': 20965,
#  "multifood's": 20966,
#  'midges': 20967,
#  'natalie': 11032,
#  'crosbie': 13884,
#  'posible': 20968,
#  'omnibus': 13885,
#  'assetsof': 20969,
#  'tricks': 13886,
#  'rs': 16402,
#  'kilogram': 20970,
#  'pruning': 25366,
#  'dyer': 13887,
#  'dyes': 20971,
#  'legislatures': 20972,
#  'scm': 16403,
#  'sci': 9408,
#  'riedel': 20973,
#  'ceramic': 16404,
#  'unitholders': 6704,
#  'scb': 13888,
#  'dn11': 20974,
#  'conditionality': 20975,
#  "stock's": 13810,
#  'masland': 20976,
#  'causes': 7609,
#  'riots': 10094,
#  'norf': 20977,
#  'nord': 9409,
#  'midwest': 3896,
#  'tamils': 13889,
#  'ofthe': 16405,
#  "colombia's": 3424,
#  '24th': 11033,
#  'sant': 20978,
#  'moines': 10095,
#  'electrotechnical': 22580,
#  'proceeded': 24537,
#  'sanz': 20979,
#  'insufficiently': 13890,
#  'sang': 20980,
#  'sand': 5953,
#  'bracho': 16407,
#  'small': 808,
#  'workloads': 20981,
#  'sank': 6705,
#  'kemper': 20982,
#  'abbreviated': 16408,
#  'quicker': 13891,
#  '199': 3805,
#  '198': 3246,
#  '195': 2664,
#  '194': 3083,
#  '197': 4313,
#  '196': 3897,
#  '191': 2853,
#  '190': 2202,
#  '193': 3484,
#  '192': 3353,
#  'past': 585,
#  'fractionation': 20983,
#  'displays': 20984,
#  'pass': 3084,
#  'investment': 205,
#  'quals': 27065,
#  'quicken': 16409,
#  "centronic's": 20986,
#  'menswear': 20987,
#  'clock': 16410,
#  'teape': 20988,
#  'teapa': 20989,
#  'prevailed': 10096,
#  'hebei': 9410,
#  ...}

# %%
index_word = {v:k for k,v in word_index.items()}

# %%
' '.join(index_word[id] for id in x_train[0])
# Out:
# 'START period ended december 31 shr profit 11 cts vs loss 24 cts net profit 224 271 vs loss 511 349 revs 7 258 688 vs 7 200 349 reuter 3'

# %%
(all_x_train,_),(all_x_valid,_) = reuters.load_data()

# %%
' '.join(index_word[id] for id in all_x_train[0])
# Out:
# 'START mcgrath rentcorp said as a result of its december acquisition of space co it expects earnings per share in 1987 of 1 15 to 1 30 dlrs per share up from 70 cts in 1986 the company said pretax net should rise to nine to 10 mln dlrs from six mln dlrs in 1986 and rental operation revenues to 19 to 22 mln dlrs from 12 5 mln dlrs it said cash flow per share this year should be 2 50 to three dlrs reuter 3'

# %% [markdown]
# **Padding**

# %%
x_train = pad_sequences(x_train, maxlen=max_review_length, padding=pad_type, truncating=trunc_type, value=0)
x_test = pad_sequences(x_test, maxlen=max_review_length, padding=pad_type, truncating=trunc_type, value=0)

# %% [markdown]
# **Configure Problem**

# %%
n_features = 50
n_timesteps_in = 5
n_timesteps_out = 2

# %%
# generate a sequence of random integers
def generate_sequence(length, n_unique):
	return [randint(0, n_unique-1) for _ in range(length)]

# one hot encode sequence
def one_hot_encode(sequence, n_unique):
	encoding = list()
	for value in sequence:
		vector = [0 for _ in range(n_unique)]
		vector[value] = 1
		encoding.append(vector)
	return array(encoding)

# decode a one hot encoded string
def one_hot_decode(encoded_seq):
	return [argmax(vector) for vector in encoded_seq]

# prepare data for the LSTM
def get_pair(n_in, n_out, cardinality):
	# generate random sequence
	sequence_in = generate_sequence(n_in, cardinality)
	sequence_out = sequence_in[:n_out] + [0 for _ in range(n_in-n_out)]
	# one hot encode
	X = one_hot_encode(sequence_in, cardinality)
	y = one_hot_encode(sequence_out, cardinality)
	# reshape as 3D
	X = X.reshape((1, X.shape[0], X.shape[1]))
	y = y.reshape((1, y.shape[0], y.shape[1]))
	return X,y

# %% [markdown]
# **bleu score function**

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu

# %%
def Bleu_score( reference, test):
  return sentence_bleu(  reference, test)

# %% [markdown]
# **Model Architecture**

# %%
# define model
model = Sequential()
model.add(LSTM(150, input_shape=(n_timesteps_in, n_features), return_sequences=True))
model.add(AttentionDecoder(150, n_features))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %% [markdown]
# **Model Summary**

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 5, 150)            120600
# _________________________________________________________________
# AttentionDecoder (AttentionD (None, 5, 50)             243300
# =================================================================
# Total params: 363,900
# Trainable params: 363,900
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Model Compilation**

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %% [markdown]
# **Model Training**

# %%
for epoch in range(5000):
	# generate new random sequence
	X,y = get_pair(n_timesteps_in, n_timesteps_out, n_features)
	# fit model for one epoch on this sequence
	model.fit(X, y, epochs=1, verbose=2)
# evaluate LSTM
total, correct = 100, 0
for _ in range(total):
	X,y = get_pair(n_timesteps_in, n_timesteps_out, n_features)
	yhat = model.predict(X, verbose=0)
	if array_equal(one_hot_decode(y[0]), one_hot_decode(yhat[0])):
		correct += 1
print('Accuracy: %.2f%%' % (float(correct)/float(total)*100.0))
# spot check some examples
for _ in range(10):
	X,y = get_pair(n_timesteps_in, n_timesteps_out, n_features)
	yhat = model.predict(X, verbose=0)
	print('Expected:', one_hot_decode(y[0]), 'Predicted', one_hot_decode(yhat[0]))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
#  - 3s - loss: 3.9007 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 3.8983 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 3.8904 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 3.8760 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.8536 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.7966 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.8493 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.8054 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.7714 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.7479 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.7037 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.7229 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.6899 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.5784 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 3.5500 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.5388 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.4940 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.4466 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.5169 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.2776 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.2835 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 3.0917 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 2.9755 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 2.7726 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 2.4829 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 2.4070 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 2.2162 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.9410 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.9250 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7349 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6599 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6665 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6509 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6729 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.8320 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7960 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.8094 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.8180 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.8338 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.8980 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6653 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6668 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6252 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7402 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6704 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6642 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5707 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6030 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5749 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6284 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5989 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6710 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6123 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5886 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6825 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6497 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6095 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5920 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7152 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6627 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6110 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6455 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6168 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6369 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6565 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6338 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6040 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6331 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6160 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6471 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5946 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6424 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5259 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4875 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5702 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4860 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5894 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5391 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7920 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6416 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5604 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7878 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5804 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4786 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6988 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7010 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7335 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6951 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5734 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5807 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5405 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7313 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7234 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5909 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6718 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6923 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4986 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5823 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5744 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6203 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4234 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7113 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4969 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.2017 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 1.7283 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5020 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5797 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5940 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 1.5337 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6044 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5932 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5858 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6773 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7030 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5455 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5445 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4912 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5519 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4979 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5497 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5461 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5676 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6053 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5916 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6958 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5561 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.2421 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 1.5896 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6008 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5448 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7003 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6022 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4742 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5299 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5771 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.3699 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5183 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6862 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6188 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6128 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6713 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.1121 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 1.5553 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6773 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5958 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7026 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6283 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5554 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7087 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5516 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6559 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5385 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5774 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5799 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4740 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4898 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6254 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4766 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5184 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4743 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 1.5889 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6784 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5913 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5094 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5975 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6122 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4680 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6557 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6310 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.0629 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 1.5413 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6373 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.4159 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5637 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6070 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5810 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6024 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6144 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.6561 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.7742 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.5981 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 1.